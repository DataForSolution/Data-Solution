# %% [markdown]
# # Chest CT evaluation demo
#
# This notebook uses synthetic labels only. It demonstrates deterministic evaluation mechanics; it does not estimate clinical performance.

# %%
from chest_ct_portfolio.evaluation import classification_metrics

# %% [markdown]
# ## Why deterministic ordering matters
#
# For a real validation/test generator, disable shuffling before prediction so prediction order matches the ground-truth label order.

# %%
y_true = [0, 0, 1, 1, 2, 2, 3, 3]
y_pred = [0, 1, 1, 1, 2, 3, 3, 0]
classification_metrics(y_true, y_pred, labels=[0, 1, 2, 3])

# %% [markdown]
# ## Clinical boundary
#
# A sound confusion matrix is necessary for evaluation, but it is not sufficient for clinical validation. Patient-level independence, representative data, external validation, and uncertainty analysis are still required.
